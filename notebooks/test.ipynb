# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.randn(10)
y = np.random.randn(10)

plt.scatter(x, y)
plt.show()

# %%
np.random
# Out:
# <module 'numpy.random' from '/home/heka/anaconda3/lib/python3.7/site-packages/numpy/random/__init__.py'>
